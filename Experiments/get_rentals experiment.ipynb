# %% [markdown]
# ### Rental Data

# %% [markdown]
# Lets get a basic download of rentals

# %%
import pandas as pd
import requests
import concurrent.futures
import json
from datetime import datetime

# %%
URL = "https://www.realtor.com/api/v1/hulk_main_srp"

QUERYSTRING = {"client_id": "rdc-x", "schema": "vesta"}

HEADERS = {
    "authority": "www.realtor.com",
    "accept": "application/json",
    "accept-language": "en-US,en;q=0.5",
    "content-type": "application/json",
    "origin": "https://www.realtor.com",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "sec-gpc": "1",
    "user-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36"
}

QUERY = """
    query ConsumerSearchMainQuery(
        $query: HomeSearchCriteria!
        $limit: Int
        $offset: Int
        $sort: [SearchAPISort]
        $sort_type: SearchSortType
        $client_data: JSON
        $bucket: SearchAPIBucket
        ) {
        home_search: home_search(
            query: $query
            sort: $sort
            limit: $limit
            offset: $offset
            sort_type: $sort_type
            client_data: $client_data
            bucket: $bucket
        ) {
            count
            total
            results {
            property_id
            list_price
            primary
            rent_to_own {
                rent
                right_to_purchase
                provider
            }
            primary_photo(https: true) {
                href
            }
            source {
                id
                agents {
                office_name
                }
                type
                spec_id
                plan_id
            }
            community {
                property_id
                permalink
                description {
                name
                }
                advertisers {
                office {
                    hours
                    phones {
                    type
                    number
                    }
                }
                builder {
                    fulfillment_id
                }
                }
            }
            products {
                brand_name
                products
            }
            listing_id
            matterport
            virtual_tours {
                href
                type
            }
            status
            permalink
            price_reduced_amount
            other_listings {
                rdc {
                listing_id
                status
                listing_key
                primary
                }
            }
            description {
                beds
                baths
                baths_full
                baths_half
                baths_1qtr
                baths_3qtr
                garage
                stories
                type
                sub_type
                lot_sqft
                sqft
                year_built
                sold_price
                sold_date
                name
            }
            location {
                street_view_url
                address {
                line
                postal_code
                state
                state_code
                city
                coordinate {
                    lat
                    lon
                }
                }
                county {
                name
                fips_code
                }
            }
            tax_record {
                public_record_id
            }
            lead_attributes {
                show_contact_an_agent
                opcity_lead_attributes {
                cashback_enabled
                flip_the_market_enabled
                }
                lead_type
                ready_connect_mortgage {
                show_contact_a_lender
                show_veterans_united
                }
            }
            open_houses {
                start_date
                end_date
                description
                methods
                time_zone
                dst
            }
            flags {
                is_coming_soon
                is_pending
                is_foreclosure
                is_contingent
                is_new_construction
                is_new_listing(days: 14)
                is_price_reduced(days: 30)
                is_plan
                is_subdivision
            }
            list_date
            last_update_date
            coming_soon_date
            photos(limit: 2, https: true) {
                href
            }
            tags
            branding {
                type
                photo
                name
            }
            }
        }
    }
"""

# %%
results = []

offset = 0
# total gets updated, just need a value greater than offset for first iteration
total = offset + 1

# for the purpose of this example, creating a max
max_results = 200

while offset < total:

    print(f"handling offset {offset} in a total of {total}      ", end='\r')

    payload = {
        "query": QUERY,
        "variables": {
            "query": {
                "status": ["for_rent"],
                "primary": True,
                "search_location": {"location": "Burke, VA"}
            },
            "limit": 42,
            "offset": offset,
            "sort_type": "relevant",
            "by_prop_type": ["home"]
        },
        "operationName": "ConsumerSearchMainQuery",
        "callfrom": "SRP",
        "nrQueryType": "MAIN_SRP",
        "isClient": True,
    }

    response = requests.request(
        "POST", URL, json=payload, headers=HEADERS, params=QUERYSTRING)

    if response.status_code != 200:
        raise ValueError(f"Bad status code on response: {response.status_code}")

    try:
        data = response.json()['data']['home_search']
    except:
        print("Failed to read data, something went wrong with the request")
        raise

    total = data['total']

    response_results = data['results']
    offset += len(response_results)

    results += response_results

    if max_results and offset >= max_results:
        print("\n")
        print(f"Hit max: {max_results}")
        break

print("Done!                                            ")
# Out:
# Done!

# %%
results
# Out:
# [{'property_id': '6428776729',
#   'list_price': 1200,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/55adbc1ffcc52ac581b48cf47e5d1e4el-m2576841375s.jpg'},
#   'source': {'id': 'AVAL',
#    'agents': None,
#    'type': 'unit_rental',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': None,
#   'listing_id': '2960744790',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '9814-Portside-Dr_Burke_VA_22015_M64287-76729',
#   'price_reduced_amount': None,
#   'other_listings': {'rdc': [{'listing_id': '2960744790',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '2941873491',
#      'status': 'sold',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '528285170',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None}]},
#   'description': {'beds': 1,
#    'baths': 1,
#    'baths_full': 1,
#    'baths_half': None,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'single_family',
#    'sub_type': None,
#    'lot_sqft': None,
#    'sqft': None,
#    'year_built': None,
#    'sold_price': 1350000,
#    'sold_date': '2022-05-18',
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9814%20Portside%20Dr%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=YDOir3I05RvgKn4Kw9Klrf2VN0E=',
#    'address': {'line': '9814 Portside Dr',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.764381, 'lon': -77.285435}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': 'D300F7E0A078C964DEF0BABDE459574D'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_unit',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': False,
#    'is_price_reduced': None,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-10-20T19:06:59Z',
#   'last_update_date': '2023-11-10T12:04:18Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/55adbc1ffcc52ac581b48cf47e5d1e4el-m2576841375s.jpg'},
#    {'href': 'https://ap.rdcpix.com/55adbc1ffcc52ac581b48cf47e5d1e4el-m2329014877s.jpg'}],
#   'tags': ['basement', 'rental_property'],
#   'branding': [{'type': 'Office', 'photo': None, 'name': None}]},
#  {'property_id': '6368439317',
#   'list_price': 3800,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/1ea1d8260d912e4bfdc879c160f68d0cl-m269518643s.jpg'},
#   'source': {'id': 'PHPA',
#    'agents': [{'office_name': 'Samson Properties'}],
#    'type': 'mls',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': {'brand_name': 'essentials',
#    'products': ['core.agent', 'core.broker']},
#   'listing_id': '2961573361',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '9296-Mainsail-Dr_Burke_VA_22015_M63684-39317',
#   'price_reduced_amount': None,
#   'other_listings': {'rdc': [{'listing_id': '2961573361',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '2960497161',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '2937990201',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None}]},
#   'description': {'beds': 4,
#    'baths': 4,
#    'baths_full': 3,
#    'baths_half': 1,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': 2,
#    'stories': None,
#    'type': 'single_family',
#    'sub_type': None,
#    'lot_sqft': 9230,
#    'sqft': 3276,
#    'year_built': 1985,
#    'sold_price': 670000,
#    'sold_date': '2005-09-21',
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9296%20Mainsail%20Dr%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=o0N4nexQUi5OMBNFs3r0IXjy0aw=',
#    'address': {'line': '9296 Mainsail Dr',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.771223, 'lon': -77.265583}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': 'ABAEA57DC48EC3DF314005E8BB8B6AE3'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_mls',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': True,
#    'is_price_reduced': None,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-11-12T21:20:01Z',
#   'last_update_date': '2023-11-12T16:18:14Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/1ea1d8260d912e4bfdc879c160f68d0cl-m269518643s.jpg'},
#    {'href': 'https://ap.rdcpix.com/1ea1d8260d912e4bfdc879c160f68d0cl-m925724066s.jpg'}],
#   'tags': ['central_air',
#    'dining_room',
#    'dishwasher',
#    'fireplace',
#    'forced_air',
#    'hardwood_floors',
#    'pets_allowed',
#    'washer_dryer',
#    'basement',
#    'garage_1_or_more',
#    'garage_2_or_more',
#    'two_or_more_stories',
#    'updated_kitchen',
#    'large_porch',
#    'library',
#    'shopping'],
#   'branding': [{'type': 'Office',
#     'photo': None,
#     'name': 'SAMSON PROPERTIES - Chantilly'}]},
#  {'property_id': '6351673495',
#   'list_price': 3295,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/41bba7e7ef7d200d700a9e92862be6a7l-m3363634171s.jpg'},
#   'source': {'id': 'PHPA',
#    'agents': [{'office_name': None}],
#    'type': 'mls',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': {'brand_name': 'essentials',
#    'products': ['core.agent', 'core.broker']},
#   'listing_id': '2960385167',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '9469-Lapstrake-Ln_Burke_VA_22015_M63516-73495',
#   'price_reduced_amount': None,
#   'other_listings': {'rdc': [{'listing_id': '2960385167',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '2953104338',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '2933333574',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '643687894',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '642690410',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '630755442',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '641736162',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '604019818',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '554035438',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '526016818',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None}]},
#   'description': {'beds': 4,
#    'baths': 4,
#    'baths_full': 3,
#    'baths_half': 1,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': 2,
#    'stories': None,
#    'type': 'single_family',
#    'sub_type': None,
#    'lot_sqft': 11761,
#    'sqft': 3024,
#    'year_built': 1983,
#    'sold_price': 431000,
#    'sold_date': '2009-07-17',
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9469%20Lapstrake%20Ln%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=vCp5IfUlscpH24d0T19a_U0ED2M=',
#    'address': {'line': '9469 Lapstrake Ln',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.768023, 'lon': -77.271601}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': '6F33F149D5877D47C5AC8B5480C955ED'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_mls',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': True,
#    'is_new_construction': None,
#    'is_new_listing': False,
#    'is_price_reduced': None,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-10-09T19:18:44Z',
#   'last_update_date': '2023-11-13T15:39:07Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/41bba7e7ef7d200d700a9e92862be6a7l-m3363634171s.jpg'},
#    {'href': 'https://ap.rdcpix.com/41bba7e7ef7d200d700a9e92862be6a7l-m3520509518s.jpg'}],
#   'tags': ['central_air',
#    'dining_room',
#    'dishwasher',
#    'family_room',
#    'fireplace',
#    'forced_air',
#    'hardwood_floors',
#    'pets_allowed',
#    'washer_dryer',
#    'basement',
#    'garage_1_or_more',
#    'garage_2_or_more',
#    'two_or_more_stories',
#    'fenced_yard',
#    'master_suite',
#    'rental_property'],
#   'branding': [{'type': 'Office',
#     'photo': None,
#     'name': 'Promax Management, Inc.'}]},
#  {'property_id': '6588909004',
#   'list_price': 3400,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/76ba53af5fcf9fc839b4091ac9324f64l-m2979248132s.jpg'},
#   'source': {'id': 'PHPA',
#    'agents': [{'office_name': None}],
#    'type': 'mls',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': {'brand_name': 'basic_opt_in', 'products': ['core.agent']},
#   'listing_id': '2960962678',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '9089-Andromeda-Dr_Burke_VA_22015_M65889-09004',
#   'price_reduced_amount': None,
#   'other_listings': {'rdc': [{'listing_id': '2960962678',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '653474158',
#      'status': 'sold',
#      'listing_key': None,
#      'primary': None}]},
#   'description': {'beds': 4,
#    'baths': 3,
#    'baths_full': 3,
#    'baths_half': None,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'single_family',
#    'sub_type': None,
#    'lot_sqft': 9525,
#    'sqft': 3029,
#    'year_built': 1972,
#    'sold_price': 549900,
#    'sold_date': '2019-06-19',
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9089%20Andromeda%20Dr%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=UZp1egbOsdd8g2W1h4a6Dpk1DAU=',
#    'address': {'line': '9089 Andromeda Dr',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.783805, 'lon': -77.260462}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': '45F2C9A6529389219CB1B4F289EB4D97'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_mls',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': False,
#    'is_price_reduced': None,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-10-28T14:43:58Z',
#   'last_update_date': '2023-10-28T19:33:30Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/76ba53af5fcf9fc839b4091ac9324f64l-m2979248132s.jpg'},
#    {'href': 'https://ap.rdcpix.com/76ba53af5fcf9fc839b4091ac9324f64l-m631919137s.jpg'}],
#   'tags': ['central_air',
#    'central_heat',
#    'dining_room',
#    'disability_features',
#    'dishwasher',
#    'fireplace',
#    'forced_air',
#    'hardwood_floors',
#    'pets_allowed',
#    'basement',
#    'two_or_more_stories',
#    'updated_kitchen',
#    'big_yard',
#    'fenced_yard',
#    'floor_plan',
#    'rental_property'],
#   'branding': [{'type': 'Office',
#     'photo': None,
#     'name': 'Bay Property Mgmt Group Northern Virginia, LLC.'}]},
#  {'property_id': '6213097199',
#   'list_price': 2300,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': None,
#   'source': {'id': 'PHPA',
#    'agents': [{'office_name': None}],
#    'type': 'mls',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': {'brand_name': 'basic_opt_in', 'products': ['core.agent']},
#   'listing_id': '2960980125',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '6459-Fenestra-Ct-C51_Burke_VA_22015_M62130-97199',
#   'price_reduced_amount': None,
#   'other_listings': {'rdc': [{'listing_id': '2960980125',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '2283586357',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '640287954',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '637993174',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None}]},
#   'description': {'beds': 3,
#    'baths': 3,
#    'baths_full': 2,
#    'baths_half': 1,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': 2,
#    'type': 'condos',
#    'sub_type': 'condo',
#    'lot_sqft': None,
#    'sqft': 1512,
#    'year_built': 1974,
#    'sold_price': 210000,
#    'sold_date': '2003-07-29',
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=6459%20Fenestra%20Ct%20Unit%2051C%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=pQUo_3rOTyaP5j-rdQh80VPShik=',
#    'address': {'line': '6459 Fenestra Ct Unit 51C',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.777638, 'lon': -77.260706}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': '89721D67FB86D2FF7D48E0D15EB382BC'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_mls',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': False,
#    'is_price_reduced': None,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-10-30T04:15:27Z',
#   'last_update_date': '2023-11-13T16:54:46Z',
#   'coming_soon_date': None,
#   'photos': None,
#   'tags': ['central_air',
#    'disability_features',
#    'dishwasher',
#    'recreation_facilities',
#    'washer_dryer',
#    'community_swimming_pool',
#    'basement',
#    'two_or_more_stories',
#    'rental_property',
#    'shopping'],
#   'branding': [{'type': 'Office',
#     'photo': None,
#     'name': 'Bonilla and Associates LLC'}]},
#  {'property_id': '5645842542',
#   'list_price': 1550,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/c2f87a97a77f046c94ea68fffc626531l-m1334267499s.jpg'},
#   'source': {'id': 'PHPA',
#    'agents': [{'office_name': None}],
#    'type': 'mls',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': None,
#   'listing_id': '2961494199',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '9009-Sweet-Birch-Ct_Springfield_VA_22152_M56458-42542',
#   'price_reduced_amount': None,
#   'other_listings': {'rdc': [{'listing_id': '2961494199',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '2960816177',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '567321470',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None}]},
#   'description': {'beds': 1,
#    'baths': 1,
#    'baths_full': 1,
#    'baths_half': None,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'townhomes',
#    'sub_type': 'townhouse',
#    'lot_sqft': 1700,
#    'sqft': 1624,
#    'year_built': 1977,
#    'sold_price': 510000,
#    'sold_date': '2023-04-03',
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9009%20Sweet%20Birch%20Ct%2C%20Springfield%2C%20VA%2022152&size=640x480&source=outdoor&signature=NhTFXiSFp_F8S9MvrEAej6r1Z_c=',
#    'address': {'line': '9009 Sweet Birch Ct',
#     'postal_code': '22152',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Springfield',
#     'coordinate': {'lat': 38.771434, 'lon': -77.257438}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': 'F7B332567F965B816BBE7D2502334162'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_mls',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': True,
#    'is_price_reduced': None,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-11-09T18:31:26Z',
#   'last_update_date': '2023-11-09T13:30:05Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/c2f87a97a77f046c94ea68fffc626531l-m1334267499s.jpg'},
#    {'href': 'https://ap.rdcpix.com/c2f87a97a77f046c94ea68fffc626531l-m3136451119s.jpg'}],
#   'tags': ['central_air',
#    'disability_features',
#    'fireplace',
#    'basement',
#    'rental_property',
#    'shopping'],
#   'branding': [{'type': 'Office', 'photo': None, 'name': 'Ez Realty, Llc.'}]},
#  {'property_id': '6474622429',
#   'list_price': 3500,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/c2ae18fc1ffa559a36b569902fbfed70l-m3515187583s.jpg'},
#   'source': {'id': 'PHPA',
#    'agents': [{'office_name': None}],
#    'type': 'mls',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': {'brand_name': 'essentials',
#    'products': ['core.agent', 'core.broker']},
#   'listing_id': '2961516185',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '9022-Andromeda-Dr_Burke_VA_22015_M64746-22429',
#   'price_reduced_amount': None,
#   'other_listings': {'rdc': [{'listing_id': '2961516185',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '2959853569',
#      'status': 'sold',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '641488562',
#      'status': 'sold',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '602068958',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '540439114',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '532474634',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '526677762',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None}]},
#   'description': {'beds': 4,
#    'baths': 3,
#    'baths_full': 3,
#    'baths_half': None,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'single_family',
#    'sub_type': None,
#    'lot_sqft': 8944,
#    'sqft': 1560,
#    'year_built': 1971,
#    'sold_price': 451000,
#    'sold_date': '2015-06-23',
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9022%20Andromeda%20Dr%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=NuAhknCUEf8Ktcy1ySF4O_yPR1Q=',
#    'address': {'line': '9022 Andromeda Dr',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.781165, 'lon': -77.262531}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': '535C6F6B5CDAF6B4F494CF4B2B290A4A'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_mls',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': True,
#    'is_price_reduced': None,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-11-10T05:15:07Z',
#   'last_update_date': '2023-11-10T00:07:01Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/c2ae18fc1ffa559a36b569902fbfed70l-m3515187583s.jpg'},
#    {'href': 'https://ap.rdcpix.com/c2ae18fc1ffa559a36b569902fbfed70l-m2431129603s.jpg'}],
#   'tags': ['central_air',
#    'disability_features',
#    'forced_air',
#    'pets_allowed',
#    'two_or_more_stories',
#    'updated_kitchen',
#    'big_yard',
#    'beautiful_backyard',
#    'fenced_yard',
#    'shopping'],
#   'branding': [{'type': 'Office', 'photo': None, 'name': 'Homestead Realty'}]},
#  {'property_id': '6997455012',
#   'list_price': 3500,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/e151995bfbfb078138e40813f119e6e4l-m392161196s.jpg'},
#   'source': {'id': 'PHPA',
#    'agents': [{'office_name': 'SGS Real Estate'}],
#    'type': 'mls',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': {'brand_name': 'basic_opt_in', 'products': ['core.agent']},
#   'listing_id': '2960264767',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '7412-Reservation-Dr_Springfield_VA_22153_M69974-55012',
#   'price_reduced_amount': None,
#   'other_listings': {'rdc': [{'listing_id': '2960264767',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '628734102',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '2464427503',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '642785098',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '628902070',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '642097738',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '612750378',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None}]},
#   'description': {'beds': 4,
#    'baths': 3,
#    'baths_full': 2,
#    'baths_half': 1,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'single_family',
#    'sub_type': None,
#    'lot_sqft': 10710,
#    'sqft': 2100,
#    'year_built': 1977,
#    'sold_price': 177000,
#    'sold_date': '1992-11-25',
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=7412%20Reservation%20Dr%2C%20Springfield%2C%20VA%2022153&size=640x480&source=outdoor&signature=mMP9hnEXVfe-WxugyXNzf8HXxM8=',
#    'address': {'line': '7412 Reservation Dr',
#     'postal_code': '22153',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Springfield',
#     'coordinate': {'lat': 38.755367, 'lon': -77.270441}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': 'D465CFE519831F63C8E74DCDA2035262'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_mls',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': False,
#    'is_price_reduced': None,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-10-05T04:02:25Z',
#   'last_update_date': '2023-10-05T00:09:21Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/e151995bfbfb078138e40813f119e6e4l-m392161196s.jpg'},
#    {'href': 'https://ap.rdcpix.com/e151995bfbfb078138e40813f119e6e4l-m2311450013s.jpg'}],
#   'tags': ['carport',
#    'central_air',
#    'dining_room',
#    'dishwasher',
#    'forced_air',
#    'pets_allowed',
#    'washer_dryer',
#    'two_or_more_stories',
#    'fenced_yard',
#    'big_lot'],
#   'branding': [{'type': 'Office', 'photo': None, 'name': 'SGS Real Estate'}]},
#  {'property_id': '6336726000',
#   'list_price': 2950,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/b97833be5318aeca1d068e85a9eab065l-m3639597707s.jpg'},
#   'source': {'id': 'PHPA',
#    'agents': [{'office_name': 'Real Property Management Pros'}],
#    'type': 'mls',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': {'brand_name': 'essentials',
#    'products': ['core.agent', 'core.broker']},
#   'listing_id': '2959375641',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '9068-Blarney-Stone-Dr_Springfield_VA_22152_M63367-26000',
#   'price_reduced_amount': 50,
#   'other_listings': {'rdc': [{'listing_id': '2959375641',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '2540494175',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '653465838',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '623071594',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '639993750',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '611898118',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None}]},
#   'description': {'beds': 3,
#    'baths': 4,
#    'baths_full': 3,
#    'baths_half': 1,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'townhomes',
#    'sub_type': 'townhouse',
#    'lot_sqft': 1851,
#    'sqft': 2400,
#    'year_built': 1981,
#    'sold_price': 246000,
#    'sold_date': '2002-11-27',
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9068%20Blarney%20Stone%20Dr%2C%20Springfield%2C%20VA%2022152&size=640x480&source=outdoor&signature=HOw7KllfZtLxJl2carEfedPsjOk=',
#    'address': {'line': '9068 Blarney Stone Dr',
#     'postal_code': '22152',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Springfield',
#     'coordinate': {'lat': 38.774911, 'lon': -77.257365}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': '7AD7427695E247EFA4703E51F9AD9ED9'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_mls',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': False,
#    'is_price_reduced': True,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-09-05T17:09:37Z',
#   'last_update_date': '2023-11-01T14:47:48Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/b97833be5318aeca1d068e85a9eab065l-m3639597707s.jpg'},
#    {'href': 'https://ap.rdcpix.com/b97833be5318aeca1d068e85a9eab065l-m2068765161s.jpg'}],
#   'tags': ['central_air',
#    'pets_allowed',
#    'recreation_facilities',
#    'basement',
#    'two_or_more_stories',
#    'efficient',
#    'park',
#    'lake',
#    'shopping'],
#   'branding': [{'type': 'Office',
#     'photo': None,
#     'name': 'Real Property Management Pros'}]},
#  {'property_id': '9237732046',
#   'list_price': 2457,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/09b387cf535adfd832140e9927776540l-m3280094454s.jpg'},
#   'source': {'id': 'RNBT',
#    'agents': None,
#    'type': 'unit_rental',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': None,
#   'listing_id': '2953139299',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '5812-Chase-Commons-Ct-1-09204_Burke_VA_22015_M92377-32046',
#   'price_reduced_amount': 201,
#   'other_listings': {'rdc': [{'listing_id': '2953139299',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True}]},
#   'description': {'beds': 2,
#    'baths': 2,
#    'baths_full': 2,
#    'baths_half': None,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'apartment',
#    'sub_type': 'condo',
#    'lot_sqft': None,
#    'sqft': 1097,
#    'year_built': None,
#    'sold_price': None,
#    'sold_date': None,
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=5812%20Chase%20Commons%20Ct%20%23%201-09204%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=aVc1fsPYisf_ZWFQZ3-K6QLeBtI=',
#    'address': {'line': '5812 Chase Commons Ct # 1-09204',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.793781, 'lon': -77.298325}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': None,
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_unit',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': None,
#    'is_price_reduced': True,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': None,
#   'last_update_date': '2023-10-31T00:29:02Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/09b387cf535adfd832140e9927776540l-m3280094454s.jpg'},
#    {'href': 'https://ap.rdcpix.com/09b387cf535adfd832140e9927776540l-m4231897544s.jpg'}],
#   'tags': ['pets_allowed',
#    'swimming_pool',
#    'garage_1_or_more',
#    'high_ceiling',
#    'park',
#    'playground',
#    'trails',
#    'lake'],
#   'branding': [{'type': 'Office', 'photo': None, 'name': None}]},
#  {'property_id': '9878638394',
#   'list_price': 2467,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/95909b324ad09b0acfcf97b4b3e84df4l-m3280094454s.jpg'},
#   'source': {'id': 'RNBT',
#    'agents': None,
#    'type': 'unit_rental',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': None,
#   'listing_id': '2938517971',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '5812-Chase-Commons-Ct-1-11108_Burke_VA_22015_M98786-38394',
#   'price_reduced_amount': 199,
#   'other_listings': {'rdc': [{'listing_id': '2938517971',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True}]},
#   'description': {'beds': 2,
#    'baths': 2,
#    'baths_full': 2,
#    'baths_half': None,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'apartment',
#    'sub_type': 'condo',
#    'lot_sqft': None,
#    'sqft': 1097,
#    'year_built': None,
#    'sold_price': None,
#    'sold_date': None,
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=5812%20Chase%20Commons%20Ct%20%23%201-11108%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=aTihG8wKFECFczHqOi7vE6lHdm0=',
#    'address': {'line': '5812 Chase Commons Ct # 1-11108',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.793781, 'lon': -77.298325}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': None,
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_unit',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': None,
#    'is_price_reduced': True,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': None,
#   'last_update_date': '2023-11-14T12:35:16Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/95909b324ad09b0acfcf97b4b3e84df4l-m3280094454s.jpg'},
#    {'href': 'https://ap.rdcpix.com/95909b324ad09b0acfcf97b4b3e84df4l-m4231897544s.jpg'}],
#   'tags': ['pets_allowed',
#    'swimming_pool',
#    'garage_1_or_more',
#    'high_ceiling',
#    'park',
#    'playground',
#    'trails',
#    'lake'],
#   'branding': [{'type': 'Office', 'photo': None, 'name': None}]},
#  {'property_id': '5851128728',
#   'list_price': 3700,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/bd84d1776ee87cd157dbca213beca134l-m3123638645s.jpg'},
#   'source': {'id': 'PHPA',
#    'agents': [{'office_name': 'Avery-Hess, REALTORS'}],
#    'type': 'mls',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': {'brand_name': 'essentials',
#    'products': ['core.agent', 'core.broker']},
#   'listing_id': '2961316494',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '5913-Freds-Oak-Rd_Burke_VA_22015_M58511-28728',
#   'price_reduced_amount': None,
#   'other_listings': {'rdc': [{'listing_id': '2961316494',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '2958514712',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '2929918183',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '636727906',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '642386214',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '616109298',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '642189082',
#      'status': 'sold',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '606978438',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None}]},
#   'description': {'beds': 4,
#    'baths': 4,
#    'baths_full': 3,
#    'baths_half': 1,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': 2,
#    'stories': None,
#    'type': 'single_family',
#    'sub_type': None,
#    'lot_sqft': 8800,
#    'sqft': 2000,
#    'year_built': 1980,
#    'sold_price': 590000,
#    'sold_date': '2016-02-09',
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=5913%20Freds%20Oak%20Rd%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=5nU-fzvz0ydDLbQnuSliBHTle4c=',
#    'address': {'line': '5913 Freds Oak Rd',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.789995, 'lon': -77.315836}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': 'C40EC27D3113CBDCD3014065FC0B2F2E'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_mls',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': True,
#    'is_price_reduced': None,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-11-03T01:04:27Z',
#   'last_update_date': '2023-11-02T21:08:05Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/bd84d1776ee87cd157dbca213beca134l-m3123638645s.jpg'},
#    {'href': 'https://ap.rdcpix.com/bd84d1776ee87cd157dbca213beca134l-m3955178608s.jpg'}],
#   'tags': ['central_air',
#    'central_heat',
#    'dining_room',
#    'dishwasher',
#    'family_room',
#    'fireplace',
#    'pets_allowed',
#    'recreation_facilities',
#    'washer_dryer',
#    'community_swimming_pool',
#    'basement',
#    'garage_1_or_more',
#    'garage_2_or_more'],
#   'branding': [{'type': 'Office',
#     'photo': None,
#     'name': 'Avery-Hess, Realtors'}]},
#  {'property_id': '6857060205',
#   'list_price': 2700,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/6068c6e29983bb98542ac92faefe95c5l-m2033074095s.jpg'},
#   'source': {'id': 'PHPA',
#    'agents': [{'office_name': None}],
#    'type': 'mls',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': {'brand_name': 'essentials',
#    'products': ['core.agent', 'core.broker']},
#   'listing_id': '2961528708',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '5126-Dahlgreen-Pl_Burke_VA_22015_M68570-60205',
#   'price_reduced_amount': None,
#   'other_listings': {'rdc': [{'listing_id': '2961528708',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '2913845251',
#      'status': 'sold',
#      'listing_key': None,
#      'primary': None}]},
#   'description': {'beds': 3,
#    'baths': 4,
#    'baths_full': 3,
#    'baths_half': 1,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'townhomes',
#    'sub_type': 'townhouse',
#    'lot_sqft': 1430,
#    'sqft': 1782,
#    'year_built': 1972,
#    'sold_price': 375000,
#    'sold_date': '2020-05-26',
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=5126%20Dahlgreen%20Pl%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=obqMXwV0tjMt5jsmLyHVb_sHjk8=',
#    'address': {'line': '5126 Dahlgreen Pl',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.811453, 'lon': -77.270943}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': '0DA10BC242A2AFB207A747CF77D3CEEA'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_mls',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': True,
#    'is_price_reduced': None,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-11-10T17:09:00Z',
#   'last_update_date': '2023-11-10T12:08:36Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/6068c6e29983bb98542ac92faefe95c5l-m2033074095s.jpg'},
#    {'href': 'https://ap.rdcpix.com/6068c6e29983bb98542ac92faefe95c5l-m1328721197s.jpg'}],
#   'tags': ['central_air',
#    'dining_room',
#    'dishwasher',
#    'forced_air',
#    'pets_allowed',
#    'recreation_facilities',
#    'washer_dryer',
#    'community_swimming_pool',
#    'basement',
#    'two_or_more_stories',
#    'fenced_yard',
#    'shopping'],
#   'branding': [{'type': 'Office',
#     'photo': None,
#     'name': 'Real Property Management Pros'}]},
#  {'property_id': '6864359958',
#   'list_price': 3590,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/38700fbd5ffc9a1b85ce96f6a9a1302al-m1516434950s.jpg'},
#   'source': {'id': 'PHPA',
#    'agents': [{'office_name': 'BKI Group, LLC.'}],
#    'type': 'mls',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': {'brand_name': 'basic_opt_in', 'products': ['core.agent']},
#   'listing_id': '2960070080',
#   'matterport': False,
#   'virtual_tours': [{'href': 'https://tours.gemshotsmedia.com/s/idx/145225',
#     'type': None}],
#   'status': 'for_rent',
#   'permalink': '7215-Willow-Oak-Pl_Springfield_VA_22153_M68643-59958',
#   'price_reduced_amount': 200,
#   'other_listings': {'rdc': [{'listing_id': '2960070080',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '2947950448',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '2947949331',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '2940072114',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '638683538',
#      'status': 'sold',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '634047194',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '632476010',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '630966246',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None}]},
#   'description': {'beds': 3,
#    'baths': 3,
#    'baths_full': 2,
#    'baths_half': 1,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': 1,
#    'stories': None,
#    'type': 'single_family',
#    'sub_type': None,
#    'lot_sqft': 8800,
#    'sqft': 1205,
#    'year_built': 1972,
#    'sold_price': 663800,
#    'sold_date': '2022-05-31',
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=7215%20Willow%20Oak%20Pl%2C%20Springfield%2C%20VA%2022153&size=640x480&source=outdoor&signature=jnYIJJNlaLs3E76A0ARJWyvKffs=',
#    'address': {'line': '7215 Willow Oak Pl',
#     'postal_code': '22153',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Springfield',
#     'coordinate': {'lat': 38.75693, 'lon': -77.24273}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': 'F66F4DB287423E56B01C5021E45C382C'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_mls',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': False,
#    'is_price_reduced': True,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-09-28T16:13:19Z',
#   'last_update_date': '2023-10-31T12:16:29Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/38700fbd5ffc9a1b85ce96f6a9a1302al-m1516434950s.jpg'},
#    {'href': 'https://ap.rdcpix.com/38700fbd5ffc9a1b85ce96f6a9a1302al-m405630012s.jpg'}],
#   'tags': ['central_air',
#    'central_heat',
#    'disability_features',
#    'dishwasher',
#    'fireplace',
#    'pets_allowed',
#    'washer_dryer',
#    'basement',
#    'garage_1_or_more',
#    'two_or_more_stories',
#    'fenced_yard'],
#   'branding': [{'type': 'Office', 'photo': None, 'name': 'Bki Group, Llc.'}]},
#  {'property_id': '6480301006',
#   'list_price': 2450,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/5aebe8e57df38098143483faa6997c5al-b4023540398s.jpg'},
#   'source': {'id': 'PHPA',
#    'agents': [{'office_name': None}],
#    'type': 'mls',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': {'brand_name': 'essentials',
#    'products': ['core.agent', 'core.broker']},
#   'listing_id': '2960512859',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '6046-Bonnie-Bern-Ct_Burke_VA_22015_M64803-01006',
#   'price_reduced_amount': 150,
#   'other_listings': {'rdc': [{'listing_id': '2960512859',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '2944485300',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '641529206',
#      'status': 'sold',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '602705810',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None}]},
#   'description': {'beds': 3,
#    'baths': 4,
#    'baths_full': 2,
#    'baths_half': 2,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'townhomes',
#    'sub_type': 'townhouse',
#    'lot_sqft': 1500,
#    'sqft': 1232,
#    'year_built': 1974,
#    'sold_price': 350000,
#    'sold_date': '2015-07-06',
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=6046%20Bonnie%20Bern%20Ct%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=unQ2gMWVJNe87gHEutDzeoBZ4hE=',
#    'address': {'line': '6046 Bonnie Bern Ct',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.788495, 'lon': -77.260988}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': '57C98F3551AC2707B2A980EF291F285B'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_mls',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': True,
#    'is_new_construction': None,
#    'is_new_listing': False,
#    'is_price_reduced': True,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-10-13T04:16:40Z',
#   'last_update_date': '2023-11-10T15:42:58Z',
#   'coming_soon_date': None,
# ...
#   'primary_photo': {'href': 'https://ap.rdcpix.com/1cefa21b250a81704598aeb133b61f64l-m3064605625s.jpg'},
#   'source': {'id': 'PHPA',
#    'agents': [{'office_name': None}],
#    'type': 'mls',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': {'brand_name': 'essentials',
#    'products': ['core.agent', 'core.broker']},
#   'listing_id': '2960809800',
#   'matterport': False,
#   'virtual_tours': [{'href': 'https://homes.btwimages.com/mls/119005806',
#     'type': None}],
#   'status': 'for_rent',
#   'permalink': '9801-Burke-Pond-Ln_Burke_VA_22015_M68121-81341',
#   'price_reduced_amount': 200,
#   'other_listings': {'rdc': [{'listing_id': '2960809800',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True}]},
#   'description': {'beds': 4,
#    'baths': 4,
#    'baths_full': 3,
#    'baths_half': 1,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'townhomes',
#    'sub_type': 'townhouse',
#    'lot_sqft': 3146,
#    'sqft': 2566,
#    'year_built': 1984,
#    'sold_price': 530000,
#    'sold_date': '2006-06-23',
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=9801%20Burke%20Pond%20Ln%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=5gzz0iDWSxZJI3WZgMp3JthGXWI=',
#    'address': {'line': '9801 Burke Pond Ln',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.784895, 'lon': -77.283624}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': '516E1A2C717BA9F5DAE6F0719639F41D'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_mls',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': False,
#    'is_price_reduced': True,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-10-23T22:12:12Z',
#   'last_update_date': '2023-11-02T16:33:55Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/1cefa21b250a81704598aeb133b61f64l-m3064605625s.jpg'},
#    {'href': 'https://ap.rdcpix.com/1cefa21b250a81704598aeb133b61f64l-m410101132s.jpg'}],
#   'tags': ['central_air',
#    'dishwasher',
#    'family_room',
#    'fireplace',
#    'hardwood_floors',
#    'recreation_facilities',
#    'washer_dryer',
#    'community_swimming_pool',
#    'basement',
#    'updated_kitchen',
#    'master_suite'],
#   'branding': [{'type': 'Office',
#     'photo': None,
#     'name': 'Ashley Realty Group'}]},
#  {'property_id': '5819665419',
#   'list_price': 2475,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/be6292df86a9c31f793717d677fa00a4l-m2138736568s.jpg'},
#   'source': {'id': 'PHPA',
#    'agents': [{'office_name': None}],
#    'type': 'mls',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': {'brand_name': 'essentials',
#    'products': ['core.agent', 'core.broker']},
#   'listing_id': '2960117530',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '5423-Crossrail-Dr_Burke_VA_22015_M58196-65419',
#   'price_reduced_amount': 125,
#   'other_listings': {'rdc': [{'listing_id': '2960117530',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '2959477764',
#      'status': 'sold',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '2924654202',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '653538278',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '570247342',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '569503494',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None}]},
#   'description': {'beds': 3,
#    'baths': 2,
#    'baths_full': 1,
#    'baths_half': 1,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'townhomes',
#    'sub_type': 'townhouse',
#    'lot_sqft': 1200,
#    'sqft': 1200,
#    'year_built': 1973,
#    'sold_price': 305000,
#    'sold_date': '2013-08-07',
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=5423%20Crossrail%20Dr%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=5V3hOr65BqliYN00uVWGKT2qHfg=',
#    'address': {'line': '5423 Crossrail Dr',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.804019, 'lon': -77.279243}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': '4D1F8438C8C6C587EE5CAF93F38A6AF1'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_mls',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': False,
#    'is_price_reduced': False,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-09-29T19:13:33Z',
#   'last_update_date': '2023-11-09T16:10:19Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/be6292df86a9c31f793717d677fa00a4l-m2138736568s.jpg'},
#    {'href': 'https://ap.rdcpix.com/be6292df86a9c31f793717d677fa00a4l-m303323621s.jpg'}],
#   'tags': ['central_air',
#    'central_heat',
#    'dining_room',
#    'dishwasher',
#    'forced_air',
#    'recreation_facilities',
#    'washer_dryer',
#    'two_or_more_stories',
#    'updated_kitchen',
#    'fenced_yard',
#    'rental_property',
#    'open_house',
#    'park'],
#   'branding': [{'type': 'Office',
#     'photo': None,
#     'name': 'SAMSON PROPERTIES - Mclean'}]},
#  {'property_id': '6797367502',
#   'list_price': None,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ar.rdcpix.com/6053b6ed62a0dfd9833ba9acb4a75b50c-f3982177979s.jpg'},
#   'source': {'id': 'APTL',
#    'agents': None,
#    'type': 'community',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': {'brand_name': 'basic_opt_in',
#    'products': ['co_broke', 'rentals_cost_per_lead_hybrid']},
#   'listing_id': '2951091706',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '5812-Chase-Commons-Ct_Burke_VA_22015_M67973-67502',
#   'price_reduced_amount': None,
#   'other_listings': {'rdc': [{'listing_id': '2951091706',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '2956103366',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '2952827497',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '597825962',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '636148058',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '646664242',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '571405382',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '589978350',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '581288630',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '514526770',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '596512774',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '596512766',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '596512762',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '596512770',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '592506530',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '592495970',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '596190466',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '596189730',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '596189726',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '592532194',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '500603558',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '500603554',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '500603550',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '500603546',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '500603542',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None}]},
#   'description': {'beds': None,
#    'baths': None,
#    'baths_full': None,
#    'baths_half': None,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'apartment',
#    'sub_type': None,
#    'lot_sqft': None,
#    'sqft': None,
#    'year_built': 1986,
#    'sold_price': None,
#    'sold_date': None,
#    'name': 'Burke Shire Commons Apartments'},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=5812%20Chase%20Commons%20Ct%2C%20Burke%20Centre%2C%20VA%2022015&size=640x480&source=outdoor&signature=ox1u0DnRc-8BClVbpNHa7F6qBIs=',
#    'address': {'line': '5812 Chase Commons Ct',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke Centre',
#     'coordinate': {'lat': 38.794049, 'lon': -77.298311}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': '877924D298DA92C20A6AF4ADA01C60A8'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_go_direct',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': False,
#    'is_price_reduced': None,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-08-03T03:11:11Z',
#   'last_update_date': '2023-11-14T03:12:53Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ar.rdcpix.com/6053b6ed62a0dfd9833ba9acb4a75b50c-f3982177979s.jpg'},
#    {'href': 'https://ar.rdcpix.com/6053b6ed62a0dfd9833ba9acb4a75b50c-f3935722316s.jpg'}],
#   'tags': ['pets_allowed',
#    'central_air',
#    'forced_air',
#    'dishwasher',
#    'fireplace',
#    'hardwood_floors',
#    'laundry_room',
#    'community_no_fee',
#    'swimming_pool',
#    'garage_1_or_more',
#    'parking_garage',
#    'updated_kitchen',
#    'big_lot',
#    'smart_homes',
#    'park'],
#   'branding': [{'type': 'Office', 'photo': None, 'name': None}]},
#  {'property_id': '6426896130',
#   'list_price': 2800,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/1670cbdccf301c119be5cca6cdf8a830l-m2833494437s.jpg'},
#   'source': {'id': 'PHPA',
#    'agents': [{'office_name': None}],
#    'type': 'mls',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': {'brand_name': 'essentials',
#    'products': ['core.agent', 'core.broker']},
#   'listing_id': '2961621004',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '10123-Walnut-Wood-Ct_Burke_VA_22015_M64268-96130',
#   'price_reduced_amount': None,
#   'other_listings': {'rdc': [{'listing_id': '2961572320',
#      'status': 'for_sale',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '2961621004',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True},
#     {'listing_id': '2960650570',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '2960182344',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '2959794954',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '2956117253',
#      'status': 'sold',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '639098050',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '653151298',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '638167310',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '549527646',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None},
#     {'listing_id': '518818486',
#      'status': 'off_market',
#      'listing_key': None,
#      'primary': None}]},
#   'description': {'beds': 3,
#    'baths': 3,
#    'baths_full': 2,
#    'baths_half': 1,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'townhomes',
#    'sub_type': 'townhouse',
#    'lot_sqft': 1550,
#    'sqft': 2059,
#    'year_built': 1980,
#    'sold_price': 500000,
#    'sold_date': '2023-06-28',
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=10123%20Walnut%20Wood%20Ct%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=vTpwhtrNnoZvAh8ysMg5OxXBp_U=',
#    'address': {'line': '10123 Walnut Wood Ct',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.795332, 'lon': -77.293385}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': {'public_record_id': '9F4BE97448077D441C27B6C133B52A88'},
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_mls',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': True,
#    'is_price_reduced': None,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': '2023-11-14T11:06:31Z',
#   'last_update_date': '2023-11-14T06:03:44Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/1670cbdccf301c119be5cca6cdf8a830l-m2833494437s.jpg'},
#    {'href': 'https://ap.rdcpix.com/1670cbdccf301c119be5cca6cdf8a830l-m207156112s.jpg'}],
#   'tags': ['central_air',
#    'dishwasher',
#    'fireplace',
#    'recreation_facilities',
#    'washer_dryer',
#    'community_swimming_pool',
#    'basement',
#    'two_or_more_stories',
#    'updated_kitchen',
#    'tennis_court',
#    'tennis',
#    'trails'],
#   'branding': [{'type': 'Office',
#     'photo': None,
#     'name': 'CENTURY 21 Redwood Realty'}]}]

# %% [markdown]
# Seems we have listings with blank listing_date that is screwing up concats later.

# %%
for result in results:
    print(result.get('list_date'))
# Out:
# 2023-10-20T19:06:59Z
# 2023-11-12T21:20:01Z
# 2023-10-09T19:18:44Z
# 2023-10-28T14:43:58Z
# 2023-10-30T04:15:27Z
# 2023-11-09T18:31:26Z
# 2023-11-10T05:15:07Z
# 2023-10-05T04:02:25Z
# 2023-09-05T17:09:37Z
# None
# None
# 2023-11-03T01:04:27Z
# 2023-11-10T17:09:00Z
# 2023-09-28T16:13:19Z
# 2023-10-13T04:16:40Z
# 2023-10-27T19:17:28Z
# None
# 2023-11-11T02:12:00Z
# 2023-10-05T21:19:13Z
# 2023-11-02T20:19:15Z
# 2023-11-03T20:11:13Z
# 2023-09-06T20:06:33Z
# 2023-10-24T16:29:48Z
# 2023-11-10T16:25:04Z
# 2023-11-03T14:26:10Z
# 2023-08-17T04:15:24Z
# 2023-11-07T05:12:48Z
# 2023-08-03T15:20:53Z
# 2023-11-05T04:14:23Z
# 2023-11-03T21:41:49Z
# 2023-10-30T13:59:02Z
# None
# None
# 2023-11-13T03:43:05Z
# 2023-11-02T19:32:09Z
# 2023-09-24T04:12:42Z
# 2023-10-23T22:12:12Z
# 2023-09-29T19:13:33Z
# 2023-08-03T03:11:11Z
# 2023-11-14T11:06:31Z

# %%
filtered_results = [result for result in results if result.get('list_date') is None]
filtered_results
# Out:
# [{'property_id': '9237732046',
#   'list_price': 2457,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/09b387cf535adfd832140e9927776540l-m3280094454s.jpg'},
#   'source': {'id': 'RNBT',
#    'agents': None,
#    'type': 'unit_rental',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': None,
#   'listing_id': '2953139299',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '5812-Chase-Commons-Ct-1-09204_Burke_VA_22015_M92377-32046',
#   'price_reduced_amount': 201,
#   'other_listings': {'rdc': [{'listing_id': '2953139299',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True}]},
#   'description': {'beds': 2,
#    'baths': 2,
#    'baths_full': 2,
#    'baths_half': None,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'apartment',
#    'sub_type': 'condo',
#    'lot_sqft': None,
#    'sqft': 1097,
#    'year_built': None,
#    'sold_price': None,
#    'sold_date': None,
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=5812%20Chase%20Commons%20Ct%20%23%201-09204%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=aVc1fsPYisf_ZWFQZ3-K6QLeBtI=',
#    'address': {'line': '5812 Chase Commons Ct # 1-09204',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.793781, 'lon': -77.298325}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': None,
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_unit',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': None,
#    'is_price_reduced': True,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': None,
#   'last_update_date': '2023-10-31T00:29:02Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/09b387cf535adfd832140e9927776540l-m3280094454s.jpg'},
#    {'href': 'https://ap.rdcpix.com/09b387cf535adfd832140e9927776540l-m4231897544s.jpg'}],
#   'tags': ['pets_allowed',
#    'swimming_pool',
#    'garage_1_or_more',
#    'high_ceiling',
#    'park',
#    'playground',
#    'trails',
#    'lake'],
#   'branding': [{'type': 'Office', 'photo': None, 'name': None}]},
#  {'property_id': '9878638394',
#   'list_price': 2467,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/95909b324ad09b0acfcf97b4b3e84df4l-m3280094454s.jpg'},
#   'source': {'id': 'RNBT',
#    'agents': None,
#    'type': 'unit_rental',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': None,
#   'listing_id': '2938517971',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '5812-Chase-Commons-Ct-1-11108_Burke_VA_22015_M98786-38394',
#   'price_reduced_amount': 199,
#   'other_listings': {'rdc': [{'listing_id': '2938517971',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True}]},
#   'description': {'beds': 2,
#    'baths': 2,
#    'baths_full': 2,
#    'baths_half': None,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'apartment',
#    'sub_type': 'condo',
#    'lot_sqft': None,
#    'sqft': 1097,
#    'year_built': None,
#    'sold_price': None,
#    'sold_date': None,
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=5812%20Chase%20Commons%20Ct%20%23%201-11108%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=aTihG8wKFECFczHqOi7vE6lHdm0=',
#    'address': {'line': '5812 Chase Commons Ct # 1-11108',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.793781, 'lon': -77.298325}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': None,
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_unit',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': None,
#    'is_price_reduced': True,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': None,
#   'last_update_date': '2023-11-14T12:35:16Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/95909b324ad09b0acfcf97b4b3e84df4l-m3280094454s.jpg'},
#    {'href': 'https://ap.rdcpix.com/95909b324ad09b0acfcf97b4b3e84df4l-m4231897544s.jpg'}],
#   'tags': ['pets_allowed',
#    'swimming_pool',
#    'garage_1_or_more',
#    'high_ceiling',
#    'park',
#    'playground',
#    'trails',
#    'lake'],
#   'branding': [{'type': 'Office', 'photo': None, 'name': None}]},
#  {'property_id': '9859966141',
#   'list_price': 3077,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/a8a49fb5c51d5df965caf7d9ce18759el-m3280094454s.jpg'},
#   'source': {'id': 'RNBT',
#    'agents': None,
#    'type': 'unit_rental',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': None,
#   'listing_id': '2955740606',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '5812-Chase-Commons-Ct-1-13204_Burke_VA_22015_M98599-66141',
#   'price_reduced_amount': 256,
#   'other_listings': {'rdc': [{'listing_id': '2955740606',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True}]},
#   'description': {'beds': 3,
#    'baths': 2,
#    'baths_full': 2,
#    'baths_half': None,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'apartment',
#    'sub_type': 'condo',
#    'lot_sqft': None,
#    'sqft': 1467,
#    'year_built': None,
#    'sold_price': None,
#    'sold_date': None,
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=5812%20Chase%20Commons%20Ct%20%23%201-13204%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=RneSv3afKL0HALuQZtAda6uvNZY=',
#    'address': {'line': '5812 Chase Commons Ct # 1-13204',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.793781, 'lon': -77.298325}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': None,
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_unit',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': None,
#    'is_price_reduced': True,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': None,
#   'last_update_date': '2023-10-31T00:29:02Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/a8a49fb5c51d5df965caf7d9ce18759el-m3280094454s.jpg'},
#    {'href': 'https://ap.rdcpix.com/a8a49fb5c51d5df965caf7d9ce18759el-m4231897544s.jpg'}],
#   'tags': ['pets_allowed',
#    'swimming_pool',
#    'garage_1_or_more',
#    'high_ceiling',
#    'park',
#    'playground',
#    'trails',
#    'lake'],
#   'branding': [{'type': 'Office', 'photo': None, 'name': None}]},
#  {'property_id': '9476726825',
#   'list_price': 2298,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/5ca6f07423d3748a4a7ea02b51df48e6l-m3280094454s.jpg'},
#   'source': {'id': 'RNBT',
#    'agents': None,
#    'type': 'unit_rental',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': None,
#   'listing_id': '2944463449',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '5812-Chase-Commons-Ct-1-08306_Burke_VA_22015_M94767-26825',
#   'price_reduced_amount': 120,
#   'other_listings': {'rdc': [{'listing_id': '2944463449',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True}]},
#   'description': {'beds': 1,
#    'baths': 1,
#    'baths_full': 1,
#    'baths_half': None,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'apartment',
#    'sub_type': 'condo',
#    'lot_sqft': None,
#    'sqft': 835,
#    'year_built': None,
#    'sold_price': None,
#    'sold_date': None,
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=5812%20Chase%20Commons%20Ct%20%23%201-08306%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=p0CG1NBZKhZ23keBGsqV0RU96uc=',
#    'address': {'line': '5812 Chase Commons Ct # 1-08306',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.793781, 'lon': -77.298325}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': None,
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_unit',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': None,
#    'is_price_reduced': True,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': None,
#   'last_update_date': '2023-11-14T12:35:16Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/5ca6f07423d3748a4a7ea02b51df48e6l-m3280094454s.jpg'},
#    {'href': 'https://ap.rdcpix.com/5ca6f07423d3748a4a7ea02b51df48e6l-m4231897544s.jpg'}],
#   'tags': ['garage_1_or_more', 'pets_allowed', 'swimming_pool'],
#   'branding': [{'type': 'Office', 'photo': None, 'name': None}]},
#  {'property_id': '9478915955',
#   'list_price': 2156,
#   'primary': True,
#   'rent_to_own': None,
#   'primary_photo': {'href': 'https://ap.rdcpix.com/708e2080b8983be5d213edfbea0fe0b8l-m3280094454s.jpg'},
#   'source': {'id': 'RNBT',
#    'agents': None,
#    'type': 'unit_rental',
#    'spec_id': None,
#    'plan_id': None},
#   'community': None,
#   'products': None,
#   'listing_id': '2945770158',
#   'matterport': False,
#   'virtual_tours': None,
#   'status': 'for_rent',
#   'permalink': '5812-Chase-Commons-Ct-1-10306_Burke_VA_22015_M94789-15955',
#   'price_reduced_amount': None,
#   'other_listings': {'rdc': [{'listing_id': '2945770158',
#      'status': 'for_rent',
#      'listing_key': None,
#      'primary': True}]},
#   'description': {'beds': 1,
#    'baths': 1,
#    'baths_full': 1,
#    'baths_half': None,
#    'baths_1qtr': None,
#    'baths_3qtr': None,
#    'garage': None,
#    'stories': None,
#    'type': 'apartment',
#    'sub_type': 'condo',
#    'lot_sqft': None,
#    'sqft': 715,
#    'year_built': None,
#    'sold_price': None,
#    'sold_date': None,
#    'name': None},
#   'location': {'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=5812%20Chase%20Commons%20Ct%20%23%201-10306%2C%20Burke%2C%20VA%2022015&size=640x480&source=outdoor&signature=lYfLVL_IXtPHr8YJ4OMBtNha5dw=',
#    'address': {'line': '5812 Chase Commons Ct # 1-10306',
#     'postal_code': '22015',
#     'state': 'Virginia',
#     'state_code': 'VA',
#     'city': 'Burke',
#     'coordinate': {'lat': 38.793781, 'lon': -77.298325}},
#    'county': {'name': 'Fairfax', 'fips_code': '51059'}},
#   'tax_record': None,
#   'lead_attributes': {'show_contact_an_agent': True,
#    'opcity_lead_attributes': {'cashback_enabled': False,
#     'flip_the_market_enabled': False},
#    'lead_type': 'rental_basic_unit',
#    'ready_connect_mortgage': {'show_contact_a_lender': False,
#     'show_veterans_united': False}},
#   'open_houses': None,
#   'flags': {'is_coming_soon': None,
#    'is_pending': None,
#    'is_foreclosure': None,
#    'is_contingent': None,
#    'is_new_construction': None,
#    'is_new_listing': None,
#    'is_price_reduced': None,
#    'is_plan': None,
#    'is_subdivision': None},
#   'list_date': None,
#   'last_update_date': '2023-11-14T12:35:16Z',
#   'coming_soon_date': None,
#   'photos': [{'href': 'https://ap.rdcpix.com/708e2080b8983be5d213edfbea0fe0b8l-m3280094454s.jpg'},
#    {'href': 'https://ap.rdcpix.com/708e2080b8983be5d213edfbea0fe0b8l-m4231897544s.jpg'}],
#   'tags': ['pets_allowed',
#    'swimming_pool',
#    'garage_1_or_more',
#    'high_ceiling',
#    'park',
#    'playground',
#    'trails',
#    'lake'],
#   'branding': [{'type': 'Office', 'photo': None, 'name': None}]}]

# %%
print(filtered_results[0].get('list_date') or datetime.now())
# Out:
# 2023-11-14 12:10:55.170768

# %% [markdown]
# ### Parse Code

# %%
def parse_flags(flags):
    # flags example value
    # {'is_coming_soon': None, 'is_new_listing': False, 'is_price_reduced': None, 'is_foreclosure': None, 'is_new_construction': None, 'is_pending': True, 'is_contingent': None}

    status = []
    if flags.get('is_coming_soon') is True:
        status.append("coming soon")
    if flags.get('is_new_listing') is True:
        status.append("new listing")
    if flags.get('is_price_reduced') is True:
        status.append("price reduced")
    if flags.get('is_foreclosure') is True:
        status.append("foreclosure")
    if flags.get('is_new_construction') is True:
        status.append("new construction")
    if flags.get('is_pending') is True:
        status.append("pending")
    if flags.get('is_contingent') is True:
        status.append("contingent")

    return ", ".join(status)

# %%
df = pd.DataFrame()

for result in results:

    if result['location']['address'].get('coordinate'):
        lat = result['location']['address'].get('coordinate', {}).get('lat')
        lon = result['location']['address'].get('coordinate', {}).get('lon')
    else:
        lat, lon = None, None

    interdf = pd.DataFrame([{
            'id': result.get('property_id'),
            'list date': pd.to_datetime(result.get('list_date') or datetime.now()),
            'status': result['status'],
            'flags': parse_flags(result['flags']),
            'home type': result['description']['type'],
            'year built': result.get('description').get('year_built', ""),
            'price': result['list_price'],
            'hoa fee': result.get('hoa', {}).get('fee', None),
            'beds': result['description']['beds'],
            'baths': result['description']['baths'],
            'interior sqft': result['description']['sqft'],
            'lot sqft': result['description']['lot_sqft'],
            'address': f"{result['location']['address']['line']} {result['location']['address']['city']}, {result['location']['address']['state_code']} {result['location']['address']['postal_code']}",
            'addresss line': result['location']['address']['line'],
            'city': result['location']['address']['city'],
            'state': result['location']['address']['state_code'],
            'zipcode': result['location']['address']['postal_code'],
            'latitude': lat,
            'longitude': lon,
            'url': f"https://www.realtor.com/realestateandhomes-detail/{result['permalink']}",
        }])
    df = pd.concat([df, interdf])

print(df.shape)
df.head()
# Out:
# (40, 20)
# /var/folders/2l/88ghk2rn2572_7lbmkzzf9r00000gn/T/ipykernel_2663/4075686559.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, interdf])
#            id                  list date    status        flags  \
# 0  6428776729  2023-10-20 19:06:59+00:00  for_rent
# 0  6368439317  2023-11-12 21:20:01+00:00  for_rent  new listing
# 0  6351673495  2023-10-09 19:18:44+00:00  for_rent   contingent
# 0  6588909004  2023-10-28 14:43:58+00:00  for_rent
# 0  6213097199  2023-10-30 04:15:27+00:00  for_rent
#
#        home type year built price hoa fee beds baths interior sqft lot sqft  \
# 0  single_family       None  1200    None    1     1          None     None
# 0  single_family       1985  3800    None    4     4          3276     9230
# 0  single_family       1983  3295    None    4     4          3024    11761
# 0  single_family       1972  3400    None    4     3          3029     9525
# 0         condos       1974  2300    None    3     3          1512     None
#
#                                      address              addresss line  \
# 0           9814 Portside Dr Burke, VA 22015           9814 Portside Dr
# 0           9296 Mainsail Dr Burke, VA 22015           9296 Mainsail Dr
# 0          9469 Lapstrake Ln Burke, VA 22015          9469 Lapstrake Ln
# 0          9089 Andromeda Dr Burke, VA 22015          9089 Andromeda Dr
# 0  6459 Fenestra Ct Unit 51C Burke, VA 22015  6459 Fenestra Ct Unit 51C
#
#     city state zipcode   latitude  longitude  \
# 0  Burke    VA   22015  38.764381 -77.285435
# 0  Burke    VA   22015  38.771223 -77.265583
# 0  Burke    VA   22015  38.768023 -77.271601
# 0  Burke    VA   22015  38.783805 -77.260462
# 0  Burke    VA   22015  38.777638 -77.260706
#
#                                                  url
# 0  https://www.realtor.com/realestateandhomes-det...
# 0  https://www.realtor.com/realestateandhomes-det...
# 0  https://www.realtor.com/realestateandhomes-det...
# 0  https://www.realtor.com/realestateandhomes-det...
# 0  https://www.realtor.com/realestateandhomes-det...
