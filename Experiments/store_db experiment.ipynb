# %% [markdown]
# # Scrape Realtor.com Listings

# %%
import pandas as pd
import requests
from time import sleep
import concurrent.futures
import json
from datetime import datetime
import re

# %% [markdown]
# ## Setup Headers and Other Constants

# %%
URL = "https://www.realtor.com/api/v1/hulk_main_srp"

QUERYSTRING = {"client_id": "rdc-x", "schema": "vesta"}

HEADERS = {
    "authority": "www.realtor.com",
    "accept": "application/json",
    "accept-language": "en-US,en;q=0.5",
    "content-type": "application/json",
    "origin": "https://www.realtor.com",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "sec-gpc": "1",
    "user-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36"
}

QUERY = """
    query ConsumerSearchMainQuery(
        $query: HomeSearchCriteria!
        $limit: Int
        $offset: Int
        $sort: [SearchAPISort]
        $sort_type: SearchSortType
        $client_data: JSON
        $bucket: SearchAPIBucket
        ) {
        home_search: home_search(
            query: $query
            sort: $sort
            limit: $limit
            offset: $offset
            sort_type: $sort_type
            client_data: $client_data
            bucket: $bucket
        ) {
            count
            total
            results {
            property_id
            list_price
            primary
            rent_to_own {
                rent
                right_to_purchase
                provider
            }
            primary_photo(https: true) {
                href
            }
            source {
                id
                agents {
                office_name
                }
                type
                spec_id
                plan_id
            }
            community {
                property_id
                permalink
                description {
                name
                }
                advertisers {
                office {
                    hours
                    phones {
                    type
                    number
                    }
                }
                builder {
                    fulfillment_id
                }
                }
            }
            products {
                brand_name
                products
            }
            listing_id
            matterport
            virtual_tours {
                href
                type
            }
            status
            permalink
            price_reduced_amount
            other_listings {
                rdc {
                listing_id
                status
                listing_key
                primary
                }
            }
            description {
                beds
                baths
                baths_full
                baths_half
                baths_1qtr
                baths_3qtr
                garage
                stories
                type
                sub_type
                lot_sqft
                sqft
                year_built
                sold_price
                sold_date
                name
            }
            location {
                street_view_url
                address {
                line
                postal_code
                state
                state_code
                city
                coordinate {
                    lat
                    lon
                }
                }
                county {
                name
                fips_code
                }
            }
            tax_record {
                public_record_id
            }
            lead_attributes {
                show_contact_an_agent
                opcity_lead_attributes {
                cashback_enabled
                flip_the_market_enabled
                }
                lead_type
                ready_connect_mortgage {
                show_contact_a_lender
                show_veterans_united
                }
            }
            open_houses {
                start_date
                end_date
                description
                methods
                time_zone
                dst
            }
            flags {
                is_coming_soon
                is_pending
                is_foreclosure
                is_contingent
                is_new_construction
                is_new_listing(days: 14)
                is_price_reduced(days: 30)
                is_plan
                is_subdivision
            }
            list_date
            last_update_date
            coming_soon_date
            photos(limit: 2, https: true) {
                href
            }
            tags
            branding {
                type
                photo
                name
            }
            }
        }
    }
"""

# %% [markdown]
# ## Pull from Realtor

# %%
results = []

offset = 0
# total gets updated, just need a value greater than offset for first iteration
total = offset + 1

# for the purpose of this example, creating a max
max_results = 200

while offset < total:

    print(f"handling offset {offset} in a total of {total}      ", end='\r')

    payload = {
        "query": QUERY,
        "variables": {
            "query": {
                "status": ["for_sale", "ready_to_build"],
                "primary": True,
                "search_location": {"location": "Burke, VA"}
            },
            "limit": 42,
            "offset": offset,
            "sort_type": "relevant",
            "by_prop_type": ["home"]
        },
        "operationName": "ConsumerSearchMainQuery",
        "callfrom": "SRP",
        "nrQueryType": "MAIN_SRP",
        "isClient": True,
    }

    response = requests.request(
        "POST", URL, json=payload, headers=HEADERS, params=QUERYSTRING)

    if response.status_code != 200:
        raise ValueError(f"Bad status code on response: {response.status_code}")

    try:
        data = response.json()['data']['home_search']
    except:
        print("Failed to read data, something went wrong with the request")
        raise

    total = data['total']

    response_results = data['results']
    offset += len(response_results)

    results += response_results

    if max_results and offset >= max_results:
        print("\n")
        print(f"Hit max: {max_results}")
        break

print("Done!                                            ")
# Out:
# Done!

# %% [markdown]
# ## Parsing Data

# %% [markdown]
# We now have our listings data, my preference is to extract the parts I'm interested in and structure them within a pandas `DataFrame`

# %%
def parse_flags(flags):
    # flags example value
    # {'is_coming_soon': None, 'is_new_listing': False, 'is_price_reduced': None, 'is_foreclosure': None, 'is_new_construction': None, 'is_pending': True, 'is_contingent': None}

    status = []
    if flags.get('is_coming_soon') is True:
        status.append("coming soon")
    if flags.get('is_new_listing') is True:
        status.append("new listing")
    if flags.get('is_price_reduced') is True:
        status.append("price reduced")
    if flags.get('is_foreclosure') is True:
        status.append("foreclosure")
    if flags.get('is_new_construction') is True:
        status.append("new construction")
    if flags.get('is_pending') is True:
        status.append("pending")
    if flags.get('is_contingent') is True:
        status.append("contingent")

    return ", ".join(status)

# %%
df = pd.DataFrame()

for result in results:

    if result['location']['address'].get('coordinate'):
        lat = result['location']['address'].get('coordinate', {}).get('lat')
        lon = result['location']['address'].get('coordinate', {}).get('lon')
    else:
        lat, lon = None, None

    df = pd.concat([df, pd.DataFrame([{
            'id': result['property_id'],
            'list date': pd.to_datetime(result['list_date']),
            'status': result['status'],
            'flags': parse_flags(result['flags']),
            'home type': result['description']['type'],
            'year built': result['description']['year_built'],
            'price': result['list_price'],
            'hoa fee': result.get('hoa', {}).get('fee', None),
            'beds': result['description']['beds'],
            'baths': result['description']['baths'],
            'interior sqft': result['description']['sqft'],
            'lot sqft': result['description']['lot_sqft'],
            'address': f"{result['location']['address']['line']} {result['location']['address']['city']}, {result['location']['address']['state_code']} {result['location']['address']['postal_code']}",
            'addresss line': result['location']['address']['line'],
            'city': result['location']['address']['city'],
            'state': result['location']['address']['state_code'],
            'zipcode': result['location']['address']['postal_code'],
            'latitude': lat,
            'longitude': lon,
            'url': f"https://www.realtor.com/realestateandhomes-detail/{result['permalink']}",
        }])])

print(df.shape)
df.head()
# Out:
# (50, 20)
#            id                 list date    status                    flags  \
# 0  5057900396 2023-11-17 02:04:50+00:00  for_sale              new listing
# 0  6795635263 2023-11-17 05:14:02+00:00  for_sale              new listing
# 0  6654012086 2023-11-17 05:14:02+00:00  for_sale              new listing
# 0  6635525029 2023-11-10 05:15:07+00:00  for_sale  new listing, contingent
# 0  5957870279 2023-11-09 19:17:11+00:00  for_sale                  pending
#
#        home type  year built   price hoa fee  beds  baths  interior sqft  \
# 0  single_family        1977  850000    None     4      4           3528
# 0  single_family        1987  899888    None     4      4           3866
# 0         condos        1974  425000    None     3      3           1460
# 0         condos        1981  372500    None     3      2           1079
# 0  single_family        1977  784900    None     4      3           2034
#
#   lot sqft                                       address  \
# 0    10498    8902 Grass Valley Ct Springfield, VA 22153
# 0    10485              6054 Woodedge Ct Burke, VA 22015
# 0     None   6448 Birch Leaf Ct Unit 28B Burke, VA 22015
# 0     None  5804 Cove Landing Rd Apt 202 Burke, VA 22015
# 0    16310     9210 Rockefeller Ln Springfield, VA 22153
#
#                   addresss line         city state zipcode   latitude  \
# 0          8902 Grass Valley Ct  Springfield    VA   22153  38.759675
# 0              6054 Woodedge Ct        Burke    VA   22015  38.787709
# 0   6448 Birch Leaf Ct Unit 28B        Burke    VA   22015  38.776820
# 0  5804 Cove Landing Rd Apt 202        Burke    VA   22015  38.795661
# 0           9210 Rockefeller Ln  Springfield    VA   22153  38.758991
#
#    longitude                                                url
# 0 -77.254183  https://www.realtor.com/realestateandhomes-det...
# 0 -77.279857  https://www.realtor.com/realestateandhomes-det...
# 0 -77.261609  https://www.realtor.com/realestateandhomes-det...
# 0 -77.306284  https://www.realtor.com/realestateandhomes-det...
# 0 -77.260197  https://www.realtor.com/realestateandhomes-det...

# %% [markdown]
# ### Database store

# %% [markdown]
# Now that we have the basic dataframe. Lets pop it into a basic SQL Lite database

# %% [markdown]
# https://www.geeksforgeeks.org/how-to-convert-pandas-dataframe-into-sql-in-python/#

# %%
import sqlalchemy as db

# %%
engine = db.create_engine('sqlite:///test.db')

# %% [markdown]
# Note that the `if_exists='replace` actually drops the table and replaces all the content.

# %% [markdown]
# Only use this code if the dataframe does not exist!

# %%
df.to_sql(name='House_Sale', con = engine, if_exists='Fail', index=True)
# Out:
# 46

# %% [markdown]
# Ok - Lets try and get the data back

# %%
conn = engine.connect()
metadata = db.MetaData()

# %%
housedata = db.Table('House_Sale', metadata, autoload_with=engine)

# %%
query = housedata.select()
exe = conn.execute(query)
result = exe.fetchmany(5)
for r in result:
    print(r)
# Out:
# ('6992687417', datetime.datetime(2023, 11, 16, 5, 13, 25), 'for_sale', 'new listing', 'single_family', 1993, 1399900, None, 5, 5, 5931, 26609, '6486 Lake Meadow Dr Burke, VA 22015', '6486 Lake Meadow Dr', 'Burke', 'VA', '22015', 38.778356, -77.289498, 'https://www.realtor.com/realestateandhomes-detail/6486-Lake-Meadow-Dr_Burke_VA_22015_M69926-87417')
# ('5387462722', datetime.datetime(2023, 11, 15, 18, 15, 48), 'for_sale', 'new listing', 'single_family', 1970, 799888, None, 4, 3, 2200, 9158, '9306 Winbourne Rd Burke, VA 22015', '9306 Winbourne Rd', 'Burke', 'VA', '22015', 38.806969, -77.266108, 'https://www.realtor.com/realestateandhomes-detail/9306-Winbourne-Rd_Burke_VA_22015_M53874-62722')
ail/9814-Pebble-Weigh-Ct_Burke_VA_22015_M59591-22647'), ('5698564405', '2023-11-10 05:15:07.000000', 'for_sale', 'new listing', 'single_family', 1981, 799000, None, 5, 3, 1501, 8675, '10217 Steamboat Landing Ln Burke, VA 22015', '10217 Steamboat Landing Ln', 'Burke', 'VA', '22015', 38.786666, -77.309752, 'https://www.realtor.com/realestateandhomes-detail/10217-Steamboat-Landing-Ln_Burke_VA_22015_M56985-64405'), ('6494123889', '2023-11-09 16:50:41.000000', 'for_sale', 'new listing', 'townhomes', 1980, 560000, None, 3, 3, 2023, 1550, '5701 Walnut Wood Ln Burke, VA 22015', '5701 Walnut Wood Ln', 'Burke', 'VA', '22015', 38.79649, -77.295153, 'https://www.realtor.com/realestateandhomes-detail/5701-Walnut-Wood-Ln_Burke_VA_22015_M64941-23889'), ('5995152669', '2023-10-20 04:03:09.000000', 'for_sale', 'price reduced, contingent', 'single_family', 1982, 930000, None, 4, 4, 2476, 10006, '5603 Bakersville Ln Burke, VA 22015', '5603 Bakersville Ln', 'Burke', 'VA', '22015', 38.797937, -77.263053, 'https://www.realtor.com/realestateandhomes-detail/5603-Bakersville-Ln_Burke_VA_22015_M59951-52669'), ('5157781713', '2023-11-08 17:12:35.000000', 'for_sale', 'pending', 'single_family', 1977, 769900, None, 4, 3, 2182, 16166, '5624 Signal Point Ct Burke, VA 22015', '5624 Signal Point Ct', 'Burke', 'VA', '22015', 38.797391, -77.249788, 'https://www.realtor.com/realestateandhomes-detail/5624-Signal-Point-Ct_Burke_VA_22015_M51577-81713'), ('5243639661', '2023-08-18 00:03:43.000000', 'for_sale', '', 'condos', 1982, 229000, None, 2, 1, 726, None, '10310 Rein Commons Ct Unit 3G Burke, VA 22015', '10310 Rein Commons Ct Unit 3G', 'Burke', 'VA', '22015', 38.794856, -77.301015, 'https://www.realtor.com/realestateandhomes-detail/10310-Rein-Commons-Ct-G3_Burke_VA_22015_M52436-39661'), ('6681763137', '2023-11-02 04:14:59.000000', 'for_sale', 'new listing', 'single_family', 1980, 799900, None, 4, 3, 2179, 18804, '10724 Freds Oak Ct Burke, VA 22015', '10724 Freds Oak Ct', 'Burke', 'VA', '22015', 38.790377, -77.318132, 'https://www.realtor.com/realestateandhomes-detail/10724-Freds-Oak-Ct_Burke_VA_22015_M66817-63137'), ('6426896130', '2023-11-12 19:14:51.000000', 'for_sale', 'new listing', 'townhomes', 1980, 649000, None, 3, 3, 2059, 1550, '10123 Walnut Wood Ct Burke, VA 22015', '10123 Walnut Wood Ct', ' ...

# %% [markdown]
# ### Merging data

# %% [markdown]
# Lets implement the situation where we have new records.

# %%
ds = pd.read_sql("SELECT * FROM House_Sale", con=engine)

# %%
merged_df = pd.merge(ds, df, on=['id', 'status'])
# Update the dataframe in the database with the merged records

# %%
df.shape
# Out:
# (50, 20)

# %%
df
# Out:
#            id                 list date    status                       flags  \
# 0  5057900396 2023-11-17 02:04:50+00:00  for_sale                 new listing
# 42  6121938926  2023-10-26 00:31:37.000000  for_sale
# 43  6579950656  2023-10-30 19:55:46.000000  for_sale
# 44  6628940697  2023-10-12 14:34:34.000000  for_sale
# 45  6094673034  2023-11-16 05:13:25.000000  for_sale
#
#                        flags_x    home type_x  year built_x  price_x  \
# 0                  new listing  single_family          1993  1399900
# 1                  new listing  single_family          1970   799888
# 2      new listing, contingent         condos          1981   372500
# 3                      pending  single_family          1977   784900
# 4      new listing, contingent  single_family          1978   649900
# 5                  new listing  single_family          1981   799000
# 6                  new listing      townhomes          1980   560000
# 7    price reduced, contingent  single_family          1982   930000
# 8                      pending  single_family          1977   769900
# 9                                      condos          1982   229000
# 10                 new listing  single_family          1980   799900
# 11                 new listing      townhomes          1980   649000
# 12               price reduced      townhomes          1989   598000
# 13                                     condos          1986   289000
# 14  new listing, price reduced      townhomes          1977   589900
# 15                  contingent  single_family          1978   789000
# 16     new listing, contingent         condos          1981   275000
# 17                  contingent      townhomes          1989   595000
# 18     new listing, contingent      townhomes          1981   525000
# 19                  contingent      townhomes          1979   549000
# 20                  contingent  single_family          1968   799900
# 21                     pending  single_family          1971   875000
# 22                  contingent  single_family          1990  1225000
# 23     new listing, contingent      townhomes          1979   550000
# 24                                  townhomes          1972   537000
# 25                  contingent      townhomes          1986   599999
# 26     new listing, contingent      townhomes          1988   599900
# 27                  contingent      townhomes          1971   689900
# 28                     pending         condos          1981   325000
# 29                                  townhomes          1970   599000
# 30                     pending      townhomes          1986   590000
# 31                     pending  single_family          1973   799900
# 32      price reduced, pending  single_family          1986   850000
# 33                     pending      townhomes          1973   550000
# 34                     pending         condos          1980   370000
# 35                     pending      townhomes          1978   559500
# 36                     pending  single_family          1986   875000
# 37                  contingent         condos          1986   479900
# 38                     pending         condos          1984   334999
# 39                     pending      townhomes          1984   597875
# 40                     pending      townhomes          1972   515000
# 41      price reduced, pending      townhomes          1983   535000
# 42                     pending      townhomes          2002   790000
# 43                     pending      townhomes          1991   625000
# 44                     pending      townhomes          1972   590000
# 45                 new listing      townhomes          1978   599999
#
#    hoa fee_x  beds_x  baths_x  ...  interior sqft_y  lot sqft_y  \
# 0       None       5        5  ...             5931       26609
# 1       None       4        3  ...             2200        9158
# 2       None       3        2  ...             1079        None
# 3       None       4        3  ...             2034       16310
# 4       None       4        3  ...             1774        2717
# 5       None       5        3  ...             1501        8675
# 6       None       3        3  ...             2023        1550
# 7       None       4        4  ...             2476       10006
# 8       None       4        3  ...             2182       16166
# 9       None       2        1  ...              726        None
# 10      None       4        3  ...             2179       18804
# 11      None       3        3  ...             2059        1550
# 12      None       2        4  ...             2036        1814
# 13      None       2        1  ...              750        None
# 14      None       4        4  ...             1320        1520
# 15      None       4        4  ...             3439        8850
# 16      None       2        1  ...              881        None
# 17      None       3        3  ...             2210        2380
# 18      None       3        3  ...             1791        1530
# 19      None       3        4  ...             1911        1447
# 20      None       4        4  ...             2528       10510
# 21      None       6        4  ...             3179       15001
# 22      None       4        4  ...             4215       12605
# 41   38.787009   -77.285783  https://www.realtor.com/realestateandhomes-det...
# 42   38.787847   -77.264984  https://www.realtor.com/realestateandhomes-det...
# 43   38.758400   -77.232882  https://www.realtor.com/realestateandhomes-det...
# 44   38.778799   -77.263420  https://www.realtor.com/realestateandhomes-det...
# 45   38.789721   -77.273432  https://www.realtor.com/realestateandhomes-det...
#
# [46 rows x 38 columns]

# %%
df.loc[df["id"] == '6963054695']
# Out:
#            id                 list date    status       flags      home type  \
# 0  6963054695 2023-10-06 15:58:37+00:00  for_sale  contingent  single_family
#
#    year built   price hoa fee  beds  baths  interior sqft lot sqft  \
# 0        1968  799900    None     4      4           2528    10510
#
#                                      address        addresss line  \
# 0  6808 Houndmaster Rd Springfield, VA 22152  6808 Houndmaster Rd
#
#           city state zipcode   latitude  longitude  \
# 0  Springfield    VA   22152  38.767167 -77.248466
#
#                                                  url
# 0  https://www.realtor.com/realestateandhomes-det...

# %%
ds.loc[ds["id"] == '6963054695']
# Out:
#             id                   list date    status       flags  \
# 20  6963054695  2023-10-06 15:58:37.000000  for_sale  contingent
#
#         home type  year built   price hoa fee  beds  baths  interior sqft  \
# 20  single_family        1968  799900    None     4      4           2528
#
#     lot sqft                                    address        addresss line  \
# 20   10510.0  6808 Houndmaster Rd Springfield, VA 22152  6808 Houndmaster Rd
#
#            city state zipcode   latitude  longitude  \
# 20  Springfield    VA   22152  38.767167 -77.248466
#
#                                                   url
# 20  https://www.realtor.com/realestateandhomes-det...

# %%
new_records = df[df['id'] != ds['id']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/rohitzacharia/Library/CloudStorage/SynologyDrive-on_demand_sync/Zachs Documents/Coding/HouseFinder/Experiments/store_db experiment.ipynb Cell 34 line 1
# ----> <a href='vscode-notebook-cell:/Users/rohitzacharia/Library/CloudStorage/SynologyDrive-on_demand_sync/Zachs%20Documents/Coding/HouseFinder/Experiments/store_db%20experiment.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> new_records = df[df['id'] != ds['id']]
#
# File ~/Library/CloudStorage/SynologyDrive-on_demand_sync/Zachs Documents/Coding/HouseFinder/house_env/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/Library/CloudStorage/SynologyDrive-on_demand_sync/Zachs Documents/Coding/HouseFinder/house_env/lib/python3.11/site-packages/pandas/core/arraylike.py:44, in OpsMixin.__ne__(self, other)
#      42 @unpack_zerodim_and_defer("__ne__")
#      43 def __ne__(self, other):
# ---> 44     return self._cmp_method(other, operator.ne)
#
# File ~/Library/CloudStorage/SynologyDrive-on_demand_sync/Zachs Documents/Coding/HouseFinder/house_env/lib/python3.11/site-packages/pandas/core/series.py:5794, in Series._cmp_method(self, other, op)
#    5791 res_name = ops.get_op_result_name(self, other)
#    5793 if isinstance(other, Series) and not self._indexed_same(other):
# -> 5794     raise ValueError("Can only compare identically-labeled Series objects")
#    5796 lvalues = self._values
#    5797 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#
# ValueError: Can only compare identically-labeled Series objects

# %%
new_records
# Out:
# Empty DataFrame
# Columns: [id, list date_x, status, flags_x, home type_x, year built_x, price_x, hoa fee_x, beds_x, baths_x, interior sqft_x, lot sqft_x, address_x, addresss line_x, city_x, state_x, zipcode_x, latitude_x, longitude_x, url_x, list date_y, flags_y, home type_y, year built_y, price_y, hoa fee_y, beds_y, baths_y, interior sqft_y, lot sqft_y, address_y, addresss line_y, city_y, state_y, zipcode_y, latitude_y, longitude_y, url_y]
# Index: []
#
# [0 rows x 38 columns]

# %%
merged_df.to_sql(name='House_Sale', con=engine, if_exists='APPEND', index=True)
